# %%
import scipy.stats
import matplotlib.pyplot as plt
import pandas as pd
import math
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('neuralNetworksOnMNIST.csv')

data
# Out:
#        index  digit  predicted_digit
# 0          0      5                5
# 1          1      0                0
# 2          2      4                4
# 3          3      1                1
# 4          4      9                9
# ...      ...    ...              ...
# 69995  69995      2                2
# 69996  69996      3                3
# 69997  69997      4                4
# 69998  69998      5                5
# 69999  69999      6                6
#
# [70000 rows x 3 columns]

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='digit', y='predicted_digit', data=data, palette="crest")
plt.title("Chiffres prédits", fontsize=14, weight='bold')
plt.xlabel("Chiffres réels")
plt.ylabel("Chiffres prédits")
plt.show()
# Out:
# /tmp/ipykernel_1431872/575313394.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='digit', y='predicted_digit', data=data, palette="crest")

# %%
plt.plot(data['digit'], data['predicted_digit'], marker='o')
plt.
plt.show()

# %%
plt.plot(data['digit'],data[''])
